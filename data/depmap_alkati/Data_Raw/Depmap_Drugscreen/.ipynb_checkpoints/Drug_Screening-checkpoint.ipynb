# %%
import pandas as pd

# %%
df_info = pd.read_csv("/gpfs/scratch/yur97/ALKATI_analysis/Depmap_Drugscreen/primary_replicate_collapsed_treatment_info.csv",
                     sep = ",")
#The first column is the treatment name, the 7th column is the Target, pass the ALK
df_temp = df_info[df_info["target"].str.contains("ALK")==True]
df_alk_info = df_temp[df_temp["moa"].str.contains("ALK","inhibitor")==True]
# Out:
#                                       column_name                broad_id  \
# 23            BRD-A23124853-001-01-4::2.5::MTS004  BRD-A23124853-001-01-4
# 198   BRD-K22149900-001-03-9::2.371298578::MTS004  BRD-K22149900-001-03-9
# 276           BRD-K39009484-001-01-4::2.5::MTS004  BRD-K39009484-001-01-4
# 351   BRD-K56981171-001-01-0::2.500008954::MTS004  BRD-K56981171-001-01-0
# 536     BRD-K99879819-001-02-1::2.5187366::MTS004  BRD-K99879819-001-02-1
# 1538             BRD-K06542892-001-01-9::2.5::HTS  BRD-K06542892-001-01-9
# 1699             BRD-K11267252-001-04-4::2.5::HTS  BRD-K11267252-001-04-4
# 2152            BRD-K24593301-001-02-3::2.54::HTS  BRD-K24593301-001-02-3
# 3015             BRD-K50140147-001-10-1::2.5::HTS  BRD-K50140147-001-10-1
# 3209             BRD-K56032964-001-02-1::2.5::HTS  BRD-K56032964-001-02-1
# 3777             BRD-K72827473-001-01-0::2.5::HTS  BRD-K72827473-001-01-0
# 3971             BRD-K78431006-001-10-2::2.5::HTS  BRD-K78431006-001-10-2
#
# ...

# %%
# pass the treatment foldchange file
df_foldchange = pd.read_csv("/gpfs/scratch/yur97/ALKATI_analysis/Depmap_Drugscreen/primary_replicate_collapsed_logfold_change.csv",
                     sep = ",")
df_foldchange.rename(columns={df_foldchange.columns[0]: "Cell_Line" }, inplace = True)
code_list = df_alk_info.iloc[:,0]
for codes in code_list:
    if codes in [columns for columns in df_foldchange.columns.values]:
        df_alk_foldchange = df_foldchange[code_list]
    else:
        print "CAN NOT FIND EXPERIMENT BATCH"
        exit()

# %%
df_foldchange
# Out:
#       Cell_Line  BRD-A00077618-236-07-6::2.5::HTS  \
# 0    ACH-000001                         -0.015577
# 1    ACH-000007                         -0.095730
# 2    ACH-000008                          0.379480
# 3    ACH-000010                          0.118890
# 4    ACH-000011                          0.145346
# 5    ACH-000012                          0.103348
# 6    ACH-000013                          0.353010
# 7    ACH-000014                          0.128302
# 8    ACH-000015                          0.166727
# 9    ACH-000018                          0.831733
# 10   ACH-000019                         -0.025927
# 11   ACH-000021                         -0.560039
# 12   ACH-000022                         -0.647900
# 13   ACH-000023                          0.037026
# 14   ACH-000026                          0.398094
# 15   ACH-000027                          0.651730
# 16   ACH-000028                         -0.770844
# 17   ACH-000030                         -0.020426
# ...
